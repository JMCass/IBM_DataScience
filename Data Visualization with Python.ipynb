# %% [markdown]
# # Matplotlib

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas #importar FigureCanvas
from matplotlib.figure import Figure #importar artista Figure
fig = Figure()
canvas = FigureCanvas(fig)

import numpy as np
x = np.random.randn(10000)

ax = fig.add_subplot(111) #crear un Eje artista

ax.hist(x, 100) #generar un histograma de 10000 números

ax.set_title('Normal distribution with $\mu=0, \sigma=1$')

fig.savefig('matplotlib_histogram.png')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(10000)
plt.hist(x,100)
plt.title(r'Normal distribution with $\mu=0, \sigma=1$')
plt.savefig('matplotlib_histogram2.png')
plt.show();

# %%
plt.plot(5,5, 'o')
plt.title('Example using matplotlib')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show();

# %%
import pandas as pd

population = {'Year': ['1980','1981','1982','1983', '1984'],
        'India': [8880,8670,8147,7338, 5704],
        'China': [5123,6682,3308,1863, 1527]
        }

india_china_df = pd.DataFrame(population, columns = ['Year', 'India', 'China'])

india_china_df = india_china_df.set_index('Year')

print (india_china_df)
# Out:
#       India  China
# Year
# 1980   8880   5123
# 1981   8670   6682
# 1982   8147   3308
# 1983   7338   1863
# 1984   5704   1527

# %%
india_china_df.plot(kind='line');

# %%
india_china_df['India'].plot(kind='hist', color = 'r');

# %%
india_china_df['China'].plot(kind='hist', color = 'g');

# %%
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx', sheet_name = 'Canada by Citizenship', skiprows = range(20), skip_footer = 2)
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can.describe()
# Out:
#              AREA          REG         DEV           1980           1981  \
# count  197.000000   197.000000  197.000000     197.000000     197.000000
# mean   913.639594  1246.477157  902.741117    1453.167513    1306.000000
# std     15.637379  1179.730385    9.782793   10784.524807    9449.373841
# min    903.000000   905.000000  901.000000       0.000000       0.000000
# 25%    903.000000   914.000000  902.000000       0.000000       0.000000
# 50%    908.000000   922.000000  902.000000      14.000000      10.000000
# 75%    935.000000   926.000000  902.000000     266.000000     299.000000
# max    999.000000  5501.000000  999.000000  143137.000000  128641.000000
#
#                 1982          1983          1984          1985          1986  \
# count     197.000000    197.000000    197.000000    197.000000    197.000000
# mean     1230.203046    905.431472    896.162437    856.304569   1008.639594
# std      8864.905615   6503.149859   6452.570413   6155.858422   7205.630681
# ...

# %%
df_can.isnull().sum().head()
# Out:
# Type        0
# Coverage    0
# OdName      0
# AREA        0
# AreaName    0
# dtype: int64

# %%
df_can.columns.values
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013], dtype=object)

# %%
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.columns
# Out:
# Index([  'Country', 'Continent',    'Region',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df_can['Total'] = df_can.sum(axis=1)

# %%
df_can.set_index('Country', inplace=True)

# %%
years = list(map(int,range(1980, 2014)))

# %%
haiti = df_can.loc['Haiti', years]
mexico = df_can.loc['Mexico', years]

# %%
haiti.index = haiti.index.map(int)
mexico = df_can.loc['Mexico', years]

haiti.plot(kind='line')
mexico.plot(kind='line')
plt.title('Immigration from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show() # need this line to show the updates made to the figure
